# %%
from matplotlib import pyplot as plt
from photometry import *
from paths import *

setup_logging()

region = 'N'
path_data = path_data(region)
path_randoms = path_randoms(region)
path_mctool = path_mctool(region)
# Out:
# WARNING: leap-second auto-update failed due to the following exception: RuntimeError('Cache is locked after 5.04 s. This may indicate an astropy bug or that kill -9 was used. If you want to unlock the cache remove the directory /global/homes/a/adematti/.astropy/cache/download/py3/lock. Lock claims to be held by process 5959.') [astropy.time.core]

# %%
data = TargetSelection.load_objects(path_data,tracer='ELG',region=region)
randoms = TargetSelection.load_objects(path_randoms,tracer='ELG',region=region)
# Out:
# [ 000000.01 ]: 11-02 12:37  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/adematti/targets_ELG_dr9m/data_NGC.fits.
# [ 000014.51 ]: 11-02 12:37  TargetSelection INFO     Selecting 11666658/11666658 targets.
# [ 000028.29 ]: 11-02 12:37  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/adematti/targets_ELG_dr9m/randoms_NGC.fits.
# [ 000036.15 ]: 11-02 12:37  TargetSelection INFO     Selecting 4760082/4760082 targets.

# %%
dens = BrickDensity(ref=randoms)
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.plot_property_map(prop='EBV',title='EBV')
dens.set_data(data=data)
dens.plot_density_map(title='target density',vmin=0,vmax=2)
dens.plot_property_map(prop='GALDEPTH_G',title='g-depth')
# Out:
# [ 000045.05 ]: 11-02 12:37  BrickDensity    INFO     Inferring brickid from randoms.
# [ 000045.05 ]: 11-02 12:37  BrickDensity    INFO     Found 81559 bricks with randoms.
# [ 000045.07 ]: 11-02 12:37  Properties      INFO     Calculating RA statistics.
# [ 000046.08 ]: 11-02 12:37  Properties      INFO     Calculating DEC statistics.
# [ 000047.12 ]: 11-02 12:37  Properties      INFO     Calculating EBV statistics.
# [ 000050.80 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_G statistics.

# %%
map = Catalogue.load(path_hp)
dens = HealpixDensity(map=map)
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data)
dens.plot_density_map(title='target density',vmin=0,vmax=2)
print(dens.properties['EBV'])
dens.plot_density_variations(prop='EBV',histos=[dens],xedges={'range':[0,0.2]})
dens.plot_density_variations(prop='STARDENS',histos=[dens],xedges={'range':[None,4000]})
for field in ['GALDEPTH','PSFSIZE']:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=True,figsize=(12,4))
    lax = lax.flatten()
    for iax,prop in enumerate(['{}_{}'.format(field,b) for b in ['G','R','Z']]):
        dens.plot_density_variations(ax=lax[iax],prop=prop,histos=[dens],xedges={'quantiles':[0.01,0.99]})
    plt.show()
densebv = dens[dens.properties['EBV']<0.04]
dens.plot_density_variations(prop='SN2TOT_FLAT',others=[densebv],histos=[dens,densebv],var_kwargs={'labels':[None,'EBV < 0.04']},xedges={'range':[100.,1500.]})
dens.plot_density_variations(prop='SN2TOT_G',others=[densebv],histos=[dens,densebv],var_kwargs={'labels':[None,'EBV < 0.04']},xedges={'range':[50.,1000.]})
dens.properties['fracPSF'] = dens.properties.get_statistics(statistic='frac',ids_catalogue=dens.get_bricks(data),values_catalogue=data.mask_morphtype('PSF'))
densebv.properties['fracPSF'] = densebv.properties.get_statistics(statistic='frac',ids_catalogue=densebv.get_bricks(data),values_catalogue=data.mask_morphtype('PSF'))
dens.plot_density_variations(prop='fracPSF',others=[densebv],histos=[dens,densebv],var_kwargs={'labels':[None,'EBV < 0.04']},xedges={'range':[0.,0.4]})
# Out:
# [ 000052.93 ]: 11-02 12:38  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.42.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000052.98 ]: 11-02 12:38  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000053.32 ]: 11-02 12:38  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000053.32 ]: 11-02 12:38  HealpixDensity  INFO     Found 97947 bricks with randoms.
# [ 000055.91 ]: 11-02 12:38  Properties      INFO     Calculating EBV statistics.
# [ 000055.99 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0031.
# [ 0.18167551 -0.7824827   0.17649943 ...  0.03250422  0.03617298
#  -0.48308084]
# [ 000056.28 ]: 11-02 12:38  Properties      INFO     Calculating STARDENS statistics.
# [ 000056.34 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0014.
# [ 000056.54 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000056.62 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0149.
# [ 000056.62 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000056.70 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0146.
# [ 000056.70 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000056.78 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0154.
# [ 000057.26 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000057.34 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0167.
# [ 000057.35 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000057.42 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0170.
# [ 000057.43 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000057.50 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0161.
# [ 000057.88 ]: 11-02 12:38  Properties      INFO     Calculating PSFDEPTH_G statistics.
# [ 000057.94 ]: 11-02 12:38  Properties      INFO     Calculating PSFDEPTH_R statistics.
# [ 000057.99 ]: 11-02 12:38  Properties      INFO     Calculating PSFDEPTH_Z statistics.
# [ 000058.06 ]: 11-02 12:38  Properties      INFO     Calculating PSFDEPTH_G statistics.
# [ 000058.11 ]: 11-02 12:38  Properties      INFO     Calculating PSFDEPTH_R statistics.
# [ 000058.17 ]: 11-02 12:38  Properties      INFO     Calculating PSFDEPTH_Z statistics.
# [ 000058.25 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_FLAT plot: 0.0032.
# [ 000058.27 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_FLAT plot: 0.0040.
# [ 000058.51 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_G plot: 0.0069.
# [ 000058.53 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_G plot: 0.0083.
# /global/homes/a/adematti/lib/photometry/density_variations.py:78: RuntimeWarning: invalid value encountered in true_divide
#   return utils.interp_digitized_statistics(ids,ids_catalogue,values=values_catalogue,statistic='sum')/utils.interp_digitized_statistics(ids,ids_catalogue,statistic='sum')
# [ 000062.92 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in fracPSF plot: 0.0013.
# [ 000062.94 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in fracPSF plot: 0.0001.

# %%
map = Catalogue.load(path_mctool)
dens = HealpixDensity(map=map)
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data)
weights = dens.properties['MCEFF'][:]
weights[weights==0.] = 1. # to avoid regions of psfdepth == 0
densmc = dens / weights
m = LinearModel(density=dens)
m.fit(props=['EBV'])
m.predict(catalogue=dens.properties,key_efficiency='LINEBV')
denslinebv = dens / dens.properties['LINEBV']
m.fit(props=['EBV','STARDENS'])
m.predict(catalogue=dens.properties,key_efficiency='LINEBVSTAR')
denslinebvstar = dens / dens.properties['LINEBVSTAR']

dens.plot_density_variations(prop='EBV',others=[densmc,denslinebv],histos=[dens],var_kwargs={'labels':[None,'+ MC weights','+ EBV weights']},xedges={'range':[0.,.2]})
dens.plot_density_variations(prop='STARDENS',others=[densmc,denslinebv,denslinebvstar],histos=[dens],var_kwargs={'labels':[None,'+ MC weights','+ EBV weights','+ STARDENS, EBV weights']},xedges={'quantiles':[0.01,0.99]})
for field in ['GALDEPTH','PSFSIZE']:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=True,figsize=(12,4))
    lax = lax.flatten()
    for iax,prop in enumerate(['{}_{}'.format(field,b) for b in ['G','R','Z']]):
        dens.plot_density_variations(ax=lax[iax],prop=prop,others=[densmc,denslinebv,denslinebvstar],histos=[dens],var_kwargs={'labels':[None,'+ MC weights','+ EBV weights','+ STARDENS, EBV weights']},xedges={'quantiles':[0.01,0.99]})
    plt.show()
# Out:
# [ 000063.13 ]: 11-02 12:38  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/adematti/mctool_ELG_dr9m/pixweight_HSC_NGC.fits.
# [ 000063.14 ]: 11-02 12:38  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000063.48 ]: 11-02 12:38  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000063.48 ]: 11-02 12:38  HealpixDensity  INFO     Found 97947 bricks with randoms.
# [ 000064.76 ]: 11-02 12:38  Properties      INFO     Calculating MCEFF statistics.
# [ 000064.77 ]: 11-02 12:38  Properties      INFO     Calculating EBV statistics.
# [ 000064.79 ]: 11-02 12:38  Properties      INFO     Calculating STARDENS statistics.
# [ 000064.84 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0015.
# [ 000064.84 ]: 11-02 12:38  Properties      INFO     Calculating EBV statistics.
# [ 000064.87 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0015.
# [ 000064.89 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0015.
# [ 000065.10 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000065.10 ]: 11-02 12:38  Properties      INFO     Calculating STARDENS statistics.
# [ 000065.12 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000065.13 ]: 11-02 12:38  Properties      INFO     Calculating STARDENS statistics.
# [ 000065.14 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000065.16 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000065.38 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000065.41 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000065.42 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000065.44 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000065.45 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000065.47 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000065.47 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000065.50 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000065.51 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000065.55 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000065.55 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000065.58 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000065.58 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000065.61 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000065.62 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000065.65 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000065.65 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000065.70 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000065.70 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000065.73 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000065.73 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000065.76 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000065.76 ]: 11-02 12:38  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000065.79 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000066.35 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000066.39 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000066.40 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000066.42 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000066.43 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000066.46 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000066.46 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000066.49 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000066.50 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000066.53 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000066.54 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000066.57 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000066.57 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000066.60 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000066.60 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000066.63 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000066.63 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000066.67 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.
# [ 000066.68 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000066.71 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.
# [ 000066.71 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000066.74 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.
# [ 000066.74 ]: 11-02 12:38  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000066.77 ]: 11-02 12:38  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.

# %%
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
denslow = BinnedDensity(ref=data,fields=['EFLUX_G'],ranges=(0.36,1.5),nbins=100)
denslow.set_randoms(randoms=data)
denslow.set_data(data=data[data['EBV']<0.1])
denslow.set_properties(weights='data')
denshigh = denslow.deepcopy()
denshigh.set_data(data=data[data['EBV']>0.1])
denshigh.set_properties(weights='data')
densratio = denshigh/denslow
densratio.plot_density_variations(prop='EFLUX_G',histos=[denslow,denshigh],var_kwargs={'errors':False,'labels':['EBV > 0.1 / EBV < 0.1']})
# Out:
# [ 000069.83 ]: 11-02 12:38  BinnedStatistic INFO     Using 100 bins.
# [ 000070.61 ]: 11-02 12:38  BinnedDensity   INFO     Inferring brickid from randoms.
# [ 000070.61 ]: 11-02 12:38  BinnedDensity   INFO     Found 100 bricks with randoms.
# [ 000079.60 ]: 11-02 12:38  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000080.43 ]: 11-02 12:38  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000081.23 ]: 11-02 12:38  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000082.03 ]: 11-02 12:38  BinnedDensity   INFO     Fraction of randoms not included in EFLUX_G plot: 0.0000.
