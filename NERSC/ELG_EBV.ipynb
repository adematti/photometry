# %%
import numpy as np
from matplotlib import pyplot as plt
from photometry import *
from paths import *

setup_logging()

region = 'N'
path_data = path_data(region)
path_randoms = path_randoms(region)
path_mctool = path_mctool(region)
# Out:
# WARNING: leap-second auto-update failed due to the following exception: RuntimeError('Cache is locked after 5.02 s. This may indicate an astropy bug or that kill -9 was used. If you want to unlock the cache remove the directory /global/homes/a/adematti/.astropy/cache/download/py3/lock. Lock claims to be held by process 5959.') [astropy.time.core]

# %%
data = TargetSelection.load_objects(path_data,tracer='ELG',region=region)
randoms = TargetSelection.load_objects(path_randoms,tracer='ELG',region=region)
# Out:
# [ 000000.01 ]: 12-09 05:27  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/adematti/targets_ELG_dr9m/data_NGC.fits.
# [ 000011.77 ]: 12-09 05:27  TargetSelection INFO     Selecting 11666658/11666658 targets.
# [ 000025.32 ]: 12-09 05:27  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/adematti/targets_ELG_dr9m/randoms_NGC.fits.
# [ 000033.66 ]: 12-09 05:27  TargetSelection INFO     Selecting 4760082/4760082 targets.

# %%
dens = BrickDensity(ref=randoms)
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.plot_property_map(prop='EBV',title='EBV')
dens.set_data(data=data)
dens.plot_density_map(title='target density',vmin=0,vmax=2)
dens.plot_property_map(prop='GALDEPTH_G',title='g-depth')
# Out:
# [ 000044.06 ]: 12-09 05:27  BrickDensity    INFO     Inferring brickid from randoms.
# [ 000044.06 ]: 12-09 05:27  BrickDensity    INFO     Found 81559 bricks with randoms.
# [ 000044.08 ]: 12-09 05:27  Properties      INFO     Calculating RA statistics.
# [ 000045.32 ]: 12-09 05:27  Properties      INFO     Calculating DEC statistics.
# [ 000046.46 ]: 12-09 05:28  Properties      INFO     Calculating EBV statistics.
# [ 000050.75 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_G statistics.

# %%
map = Catalogue.load(path_hp)
dens = HealpixDensity(map=map)
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data)
dens.plot_density_map(title='target density',vmin=0,vmax=2)
print(dens.properties['EBV'])
dens.plot_density_variations(prop='EBV',histos=[dens],xedges={'range':[0,0.2]})
dens.plot_density_variations(prop='STARDENS',histos=[dens],xedges={'range':[None,4000]})
for field in ['GALDEPTH','PSFSIZE']:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=True,figsize=(12,4))
    lax = lax.flatten()
    for iax,prop in enumerate(['{}_{}'.format(field,b) for b in ['G','R','Z']]):
        dens.plot_density_variations(ax=lax[iax],prop=prop,histos=[dens],xedges={'quantiles':[0.01,0.99]})
    plt.show()
densebv = dens[dens.properties['EBV']<0.04]
dens.plot_density_variations(prop='SN2TOT_FLAT',others=[densebv],histos=[dens,densebv],var_kwargs={'labels':[None,'EBV < 0.04']},xedges={'range':[100.,1500.]})
dens.plot_density_variations(prop='SN2TOT_G',others=[densebv],histos=[dens,densebv],var_kwargs={'labels':[None,'EBV < 0.04']},xedges={'range':[50.,1000.]})
dens.properties['fracPSF'] = dens.properties.get_statistics(statistic='frac',ids_catalogue=dens.get_bricks(data),values_catalogue=data.mask_morphtype('PSF'))
densebv.properties['fracPSF'] = densebv.properties.get_statistics(statistic='frac',ids_catalogue=densebv.get_bricks(data),values_catalogue=data.mask_morphtype('PSF'))
dens.plot_density_variations(prop='fracPSF',others=[densebv],histos=[dens,densebv],var_kwargs={'labels':[None,'EBV < 0.04']},xedges={'range':[0.,0.4]})
# Out:
# [ 000053.07 ]: 12-09 05:28  Catalogue       INFO     Loading catalogue /global/cfs/cdirs/desi/target/catalogs/dr9m/0.42.0/pixweight/main/resolve/dark/pixweight-dark.fits.
# [ 000053.12 ]: 12-09 05:28  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000053.60 ]: 12-09 05:28  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000053.61 ]: 12-09 05:28  HealpixDensity  INFO     Found 97947 bricks with randoms.
# [ 000056.47 ]: 12-09 05:28  Properties      INFO     Calculating EBV statistics.
# [ 000056.60 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0031.
# [ 0.18167551 -0.7824827   0.17649943 ...  0.03250422  0.03617298
#  -0.48308084]
# [ 000056.93 ]: 12-09 05:28  Properties      INFO     Calculating STARDENS statistics.
# [ 000056.99 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0014.
# [ 000057.21 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000057.29 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0149.
# [ 000057.29 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000057.37 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0146.
# [ 000057.38 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000057.46 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0154.
# [ 000058.01 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000058.09 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0167.
# [ 000058.10 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000058.17 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0170.
# [ 000058.17 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000058.26 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0161.
# [ 000058.67 ]: 12-09 05:28  Properties      INFO     Calculating PSFDEPTH_G statistics.
# [ 000058.74 ]: 12-09 05:28  Properties      INFO     Calculating PSFDEPTH_R statistics.
# [ 000058.80 ]: 12-09 05:28  Properties      INFO     Calculating PSFDEPTH_Z statistics.
# [ 000058.89 ]: 12-09 05:28  Properties      INFO     Calculating PSFDEPTH_G statistics.
# [ 000058.94 ]: 12-09 05:28  Properties      INFO     Calculating PSFDEPTH_R statistics.
# [ 000058.99 ]: 12-09 05:28  Properties      INFO     Calculating PSFDEPTH_Z statistics.
# [ 000059.09 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_FLAT plot: 0.0032.
# [ 000059.10 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_FLAT plot: 0.0040.
# [ 000059.35 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_G plot: 0.0069.
# [ 000059.37 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in SN2TOT_G plot: 0.0083.
# /global/homes/a/adematti/lib/photometry/density_variations.py:78: RuntimeWarning: invalid value encountered in true_divide
#   return utils.interp_digitized_statistics(ids,ids_catalogue,values=values_catalogue,statistic='sum')/utils.interp_digitized_statistics(ids,ids_catalogue,statistic='sum')
# [ 000064.75 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in fracPSF plot: 0.0013.
# [ 000064.77 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in fracPSF plot: 0.0001.

# %%
map = Catalogue.load(path_mctool)
dens = HealpixDensity(map=map)
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data)
weights = dens.properties['MCEFF'][:]
weights[weights==0.] = 1. # to avoid regions of psfdepth == 0
densmc = dens / weights
m = LinearModel(density=dens)
m.fit(props=['EBV'])
m.predict(catalogue=dens.properties,key_efficiency='LINEBV')
denslinebv = dens / dens.properties['LINEBV']
m.fit(props=['EBV','STARDENS'])
m.predict(catalogue=dens.properties,key_efficiency='LINEBVSTAR')
denslinebvstar = dens / dens.properties['LINEBVSTAR']

dens.plot_density_variations(prop='EBV',others=[densmc,denslinebv],histos=[dens],var_kwargs={'labels':[None,'+ MC weights','+ EBV weights']},xedges={'range':[0.,.2]})
dens.plot_density_variations(prop='STARDENS',others=[densmc,denslinebv,denslinebvstar],histos=[dens],var_kwargs={'labels':[None,'+ MC weights','+ EBV weights','+ STARDENS, EBV weights']},xedges={'quantiles':[0.01,0.99]})
for field in ['GALDEPTH','PSFSIZE']:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=True,figsize=(12,4))
    lax = lax.flatten()
    for iax,prop in enumerate(['{}_{}'.format(field,b) for b in ['G','R','Z']]):
        dens.plot_density_variations(ax=lax[iax],prop=prop,others=[densmc,denslinebv,denslinebvstar],histos=[dens],var_kwargs={'labels':[None,'+ MC weights','+ EBV weights','+ STARDENS, EBV weights']},xedges={'quantiles':[0.01,0.99]})
    plt.show()
# Out:
# [ 000064.98 ]: 12-09 05:28  Catalogue       INFO     Loading catalogue /global/cscratch1/sd/adematti/mctool_ELG_dr9m/pixweight_HSC_NGC.fits.
# [ 000066.02 ]: 12-09 05:28  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000066.49 ]: 12-09 05:28  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000066.49 ]: 12-09 05:28  HealpixDensity  INFO     Found 97947 bricks with randoms.
# [ 000068.18 ]: 12-09 05:28  Properties      INFO     Calculating MCEFF statistics.
# [ 000068.21 ]: 12-09 05:28  Properties      INFO     Calculating EBV statistics.
# [ 000068.23 ]: 12-09 05:28  Properties      INFO     Calculating STARDENS statistics.
# [ 000068.28 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0015.
# [ 000068.29 ]: 12-09 05:28  Properties      INFO     Calculating EBV statistics.
# [ 000068.31 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0015.
# [ 000068.33 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0015.
# [ 000068.54 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000068.55 ]: 12-09 05:28  Properties      INFO     Calculating STARDENS statistics.
# [ 000068.57 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000068.57 ]: 12-09 05:28  Properties      INFO     Calculating STARDENS statistics.
# [ 000068.59 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000068.61 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0142.
# [ 000068.84 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000068.88 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000068.88 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000068.91 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000068.91 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000068.94 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000068.94 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000068.97 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0156.
# [ 000068.98 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000069.01 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000069.02 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000069.04 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000069.05 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000069.07 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000069.08 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000069.10 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0152.
# [ 000069.11 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000069.14 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000069.15 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000069.17 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000069.18 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000069.21 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000069.21 ]: 12-09 05:28  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000069.24 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0159.
# [ 000069.82 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000069.89 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000069.90 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000069.93 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000069.93 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000069.96 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000069.96 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000069.99 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0176.
# [ 000069.99 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000070.03 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000070.03 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000070.06 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000070.06 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000070.09 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000070.10 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000070.12 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0181.
# [ 000070.13 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000070.17 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.
# [ 000070.17 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000070.20 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.
# [ 000070.21 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000070.24 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.
# [ 000070.24 ]: 12-09 05:28  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000070.27 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0171.

# %%
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
denslow = BinnedDensity(ref=data,fields=['EFLUX_G'],ranges=(0.36,1.5),nbins=100)
denslow.set_randoms(randoms=data)
denslow.set_data(data=data[data['EBV']<0.1])
denslow.set_properties(weights='data')
denshigh = denslow.deepcopy()
denshigh.set_data(data=data[data['EBV']>0.1])
denshigh.set_properties(weights='data')
densratio = denshigh/denslow
densratio.plot_density_variations(prop='EFLUX_G',histos=[denslow,denshigh],var_kwargs={'errors':False,'labels':['EBV > 0.1 / EBV < 0.1']})
# Out:
# [ 000073.80 ]: 12-09 05:28  BinnedStatistic INFO     Using 100 bins.
# [ 000074.68 ]: 12-09 05:28  BinnedDensity   INFO     Inferring brickid from randoms.
# [ 000074.68 ]: 12-09 05:28  BinnedDensity   INFO     Found 100 bricks with randoms.
# [ 000086.13 ]: 12-09 05:28  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000086.97 ]: 12-09 05:28  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000087.80 ]: 12-09 05:28  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000088.59 ]: 12-09 05:28  BinnedDensity   INFO     Fraction of randoms not included in EFLUX_G plot: 0.0000.

# %%
from scipy import special

fig,ax = plt.subplots(ncols=1,nrows=1,sharex=False,sharey=False,figsize=(6,6))
dens.plot_density_variations(ax=ax,others=[],prop='EBV',histos=[dens],var_kwargs={'labels':'DR9'},leg_kwargs={},xedges={'quantiles':[0.1,0.9]})
ebv = np.linspace(*ax.get_xlim(),num=10)
model = 1. - .25/.15*ebv # Ashley's fit
norm = 1.04 # just for plotting purposes
model = model/np.mean(model)/norm - 1.

truth = TargetSelection.load_objects(path_truth,tracer='ELG',region=None,case_sensitive=False)
truth.set_flux_from_mag(key='FLUX')
truth['REDSHIFT'] = truth['hsc_mizuki_photoz_best']
truth.region = region
mask = np.all([~np.isnan(truth[b]) for b in truth.bands],axis=0)
truth = truth[mask]

correlation = np.ones((3,3))*.5 #just given them all correlation of 0.5 for now
np.fill_diagonal(correlation,1.)
std = np.array([0.03,0.05,0.1])
flux_covariance = correlation*std*std[:,None]
efficiency = []
for ebv_ in ebv:
    mc = MCTool(truth=truth,seed=42)
    mc.set_sel_params(ebvfac=1,Rv=None,sn_band_min=6,sn_flat_min=None,sn_red_min=None)
    mc.set_sim_params(flux_covariance=flux_covariance,flux_adbias=0.,flux_mulbias=1.)
    mc.sim['EBV'] = ebv_
    mc.sim.set_estimated_transmission(key='EMW_TRANSMISSION')
    mc.sim.set_estimated_transmission(key='MW_TRANSMISSION')
    transmission = 10.**(-0.4*0.6*TargetSelection.EXT_COEFFS['G']*mc.sim['EBV'])
    transmission = transmission + (1.-transmission)*special.erf(2.*mc.truth['FLUX_G'])
    mc.sim['MW_TRANSMISSION_G'] *= transmission
    mc()
    efficiency.append(mc.get_efficiency())
efficiency = np.array(efficiency)/np.mean(efficiency)/norm - 1.

ax.plot(ebv,model,label='empirical fit',color='k')
ax.plot(ebv,efficiency,label='MC prediction',color='r')
ax.legend()
plt.show()
# Out:
# [ 000088.84 ]: 12-09 05:28  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1952.
# [ 000088.85 ]: 12-09 05:28  Catalogue       INFO     Loading catalogue /project/projectdirs/desi/users/ajross/MCdata/desi_mcsyst_truth.dr7.34ra38.-7dec-3.fits.
# [ 000089.19 ]: 12-09 05:28  TargetSelection INFO     Selecting 549181/549181 targets.
